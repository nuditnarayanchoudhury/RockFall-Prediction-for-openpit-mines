# %%
# !pip install pandas numpy scikit-learn joblib xgboost lightgbm catboost
# Out:
# Requirement already satisfied: pandas in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: joblib in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (1.4.2)
# Collecting xgboost
#   Using cached xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Collecting catboost
#   Downloading catboost-1.2.8-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from catboost) (3.9.2)
# Collecting plotly (from catboost)
#   Downloading plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: six in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nudit\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (3.1.4)
# Collecting narwhals>=1.15.1 (from plotly->catboost)
#   Downloading narwhals-2.5.0-py3-none-any.whl.metadata (11 kB)
# Using cached xgboost-3.0.5-py3-none-win_amd64.whl (56.8 MB)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.6 MB/s  0:00:00
# Downloading catboost-1.2.8-cp312-cp312-win_amd64.whl (102.4 MB)
#    ---------------------------------------- 0.0/102.4 MB ? eta -:--:--
#    ---------------------------------------- 0.5/102.4 MB 3.4 MB/s eta 0:00:31
#     --------------------------------------- 1.3/102.4 MB 3.9 MB/s eta 0:00:26
#    - -------------------------------------- 2.6/102.4 MB 4.6 MB/s eta 0:00:22
#    - -------------------------------------- 4.5/102.4 MB 5.4 MB/s eta 0:00:19
#    -- ------------------------------------- 5.5/102.4 MB 5.7 MB/s eta 0:00:18
#    -- ------------------------------------- 7.1/102.4 MB 5.7 MB/s eta 0:00:17
#    --- ------------------------------------ 8.7/102.4 MB 6.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 10.5/102.4 MB 6.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 11.8/102.4 MB 6.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 13.4/102.4 MB 6.6 MB/s eta 0:00:14
#    ----- ---------------------------------- 14.9/102.4 MB 6.6 MB/s eta 0:00:14
#    ------ --------------------------------- 16.8/102.4 MB 6.7 MB/s eta 0:00:13
#    ------- -------------------------------- 18.1/102.4 MB 6.7 MB/s eta 0:00:13
#    ------- -------------------------------- 20.2/102.4 MB 6.9 MB/s eta 0:00:12
#    -------- ------------------------------- 21.8/102.4 MB 7.0 MB/s eta 0:00:12
#    --------- ------------------------------ 23.6/102.4 MB 7.1 MB/s eta 0:00:12
#    --------- ------------------------------ 25.4/102.4 MB 7.2 MB/s eta 0:00:11
#    ---------- ----------------------------- 26.7/102.4 MB 7.1 MB/s eta 0:00:11
#    ---------- ----------------------------- 27.3/102.4 MB 7.1 MB/s eta 0:00:11
#    ----------- ---------------------------- 29.4/102.4 MB 7.1 MB/s eta 0:00:11
#    ----------- ---------------------------- 30.7/102.4 MB 7.0 MB/s eta 0:00:11
#    ------------ --------------------------- 32.2/102.4 MB 7.0 MB/s eta 0:00:10
#    ------------- -------------------------- 33.8/102.4 MB 7.1 MB/s eta 0:00:10
#    ------------- -------------------------- 35.7/102.4 MB 7.1 MB/s eta 0:00:10
#    -------------- ------------------------- 37.5/102.4 MB 7.2 MB/s eta 0:00:10
#    --------------- ------------------------ 39.3/102.4 MB 7.2 MB/s eta 0:00:09
#    --------------- ------------------------ 40.9/102.4 MB 7.3 MB/s eta 0:00:09
#    ---------------- ----------------------- 42.7/102.4 MB 7.3 MB/s eta 0:00:09
#    ----------------- ---------------------- 44.6/102.4 MB 7.4 MB/s eta 0:00:08
#    ----------------- ---------------------- 45.9/102.4 MB 7.4 MB/s eta 0:00:08
#    ------------------ --------------------- 47.7/102.4 MB 7.4 MB/s eta 0:00:08
#    ------------------- -------------------- 49.5/102.4 MB 7.4 MB/s eta 0:00:08
#    ------------------- -------------------- 51.1/102.4 MB 7.4 MB/s eta 0:00:07
#    -------------------- ------------------- 52.7/102.4 MB 7.5 MB/s eta 0:00:07
#    -------------------- ------------------- 53.7/102.4 MB 7.5 MB/s eta 0:00:07
#    --------------------- ------------------ 55.6/102.4 MB 7.4 MB/s eta 0:00:07
#    ---------------------- ----------------- 57.1/102.4 MB 7.4 MB/s eta 0:00:07
#    ---------------------- ----------------- 58.5/102.4 MB 7.4 MB/s eta 0:00:06
#    ----------------------- ---------------- 59.8/102.4 MB 7.4 MB/s eta 0:00:06
#    ----------------------- ---------------- 60.8/102.4 MB 7.4 MB/s eta 0:00:06
#    ------------------------ --------------- 62.7/102.4 MB 7.4 MB/s eta 0:00:06
#    ------------------------ --------------- 64.0/102.4 MB 7.4 MB/s eta 0:00:06
#    ------------------------- -------------- 64.7/102.4 MB 7.3 MB/s eta 0:00:06
#    ------------------------- -------------- 66.3/102.4 MB 7.3 MB/s eta 0:00:05
#    -------------------------- ------------- 68.2/102.4 MB 7.3 MB/s eta 0:00:05
#    --------------------------- ------------ 69.2/102.4 MB 7.3 MB/s eta 0:00:05
#    --------------------------- ------------ 70.0/102.4 MB 7.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 71.8/102.4 MB 7.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 73.1/102.4 MB 7.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 73.9/102.4 MB 7.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 75.0/102.4 MB 7.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 76.5/102.4 MB 7.1 MB/s eta 0:00:04
#    ------------------------------ --------- 78.4/102.4 MB 7.1 MB/s eta 0:00:04
#    ------------------------------- -------- 80.2/102.4 MB 7.1 MB/s eta 0:00:04
#    ------------------------------- -------- 81.8/102.4 MB 7.2 MB/s eta 0:00:03
#    -------------------------------- ------- 82.3/102.4 MB 7.2 MB/s eta 0:00:03
#    -------------------------------- ------- 83.4/102.4 MB 7.1 MB/s eta 0:00:03
#    --------------------------------- ------ 84.7/102.4 MB 7.0 MB/s eta 0:00:03
#    --------------------------------- ------ 86.5/102.4 MB 7.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 88.1/102.4 MB 7.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 89.4/102.4 MB 7.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 91.2/102.4 MB 7.1 MB/s eta 0:00:02
#    ------------------------------------ --- 92.8/102.4 MB 7.1 MB/s eta 0:00:02
#    ------------------------------------ --- 94.1/102.4 MB 7.1 MB/s eta 0:00:02
#    ------------------------------------- -- 95.9/102.4 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 97.5/102.4 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 99.1/102.4 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  100.7/102.4 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  102.0/102.4 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  102.2/102.4 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 102.4/102.4 MB 7.0 MB/s  0:00:14
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading plotly-6.3.0-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 8.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.8 MB 3.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/9.8 MB 4.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.8 MB 5.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.8 MB 5.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 5.4 MB/s  0:00:01
# Downloading narwhals-2.5.0-py3-none-any.whl (407 kB)
# Installing collected packages: narwhals, graphviz, xgboost, plotly, lightgbm, catboost
#
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ---------------------------------------- 0/6 [narwhals]
#    ------ --------------------------------- 1/6 [graphviz]
#    ------ --------------------------------- 1/6 [graphviz]
#    ------ --------------------------------- 1/6 [graphviz]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    ------------- -------------------------- 2/6 [xgboost]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------- ------------------- 3/6 [plotly]
#    -------------------------- ------------- 4/6 [lightgbm]
#    -------------------------- ------------- 4/6 [lightgbm]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    --------------------------------- ------ 5/6 [catboost]
#    ---------------------------------------- 6/6 [catboost]
#
# Successfully installed catboost-1.2.8 graphviz-0.21 lightgbm-4.6.0 narwhals-2.5.0 plotly-6.3.0 xgboost-3.0.5

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
df = pd.read_csv("../dataset/refined_sih_dataset_ML_ready.csv")

# %%
for col in df.select_dtypes(include=["object"]).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))

# %%
target = "rockfall_risk"
leaky_features = ["Displacement_mm", "PorePressure_kPa", "SeismicVibration_mm/s"]

X = df.drop(columns=[target] + leaky_features)
y = df[target]
groups = df["SUBDIVISION"]

# Scale features for MLP (not strictly needed for tree models)
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
models = {
    "XGBoost": XGBClassifier(
        n_estimators=200, max_depth=6, learning_rate=0.1,
        subsample=0.8, colsample_bytree=0.8,
        random_state=42, use_label_encoder=False, eval_metric="logloss"
    ),
    "LightGBM": LGBMClassifier(
        n_estimators=200, max_depth=6, learning_rate=0.1,
        subsample=0.8, colsample_bytree=0.8,
        random_state=42
    ),
    "AdaBoost": AdaBoostClassifier(
        n_estimators=200, random_state=42
    ),
    "CatBoost": CatBoostClassifier(
        iterations=200, depth=6, learning_rate=0.1,
        random_state=42, verbose=0
    ),
    "MLP": MLPClassifier(
        hidden_layer_sizes=(128, 64), activation="relu",
        solver="adam", max_iter=500, random_state=42
    ),
    "RandomForest": RandomForestClassifier(
        n_estimators=200, max_depth=10, random_state=42
    )
}

# %%
gkf = GroupKFold(n_splits=5)
results = {}

for model_name, model in models.items():
    print(f"\n🔹 Training {model_name}...")
    roc_auc_scores = []
    for fold, (train_idx, test_idx) in enumerate(gkf.split(X, y, groups=groups)):
        # Use scaled X only for MLP, otherwise raw X
        if model_name == "MLP":
            X_train, X_test = X_scaled.iloc[train_idx], X_scaled.iloc[test_idx]
        else:
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_train)
        y_pred_prob = model.predict_proba(X_test)[:, 1]
        score = roc_auc_score(y_test, y_pred_prob)
        roc_auc_scores.append(score)
        print(f"   Fold {fold+1} ROC-AUC: {score:.4f}")

    results[model_name] = np.mean(roc_auc_scores)
    print(f"✅ {model_name} Mean ROC-AUC: {results[model_name]:.4f}")
# Out:
# 🔹 Training XGBoost...
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:43:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Fold 1 ROC-AUC: 0.8322
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:43:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Fold 2 ROC-AUC: 0.8230
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:43:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Fold 3 ROC-AUC: 0.8132
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:43:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Fold 4 ROC-AUC: 0.8364
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:43:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Fold 5 ROC-AUC: 0.8395
# ✅ XGBoost Mean ROC-AUC: 0.8289
#
# 🔹 Training LightGBM...
# [LightGBM] [Info] Number of positive: 293361, number of negative: 94439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017752 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8647
# [LightGBM] [Info] Number of data points in the train set: 387800, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.756475 -> initscore=1.133450
# [LightGBM] [Info] Start training from score 1.133450
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    Fold 1 ROC-AUC: 0.8165
# [LightGBM] [Info] Number of positive: 301746, number of negative: 99904
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019005 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8700
# [LightGBM] [Info] Number of data points in the train set: 401650, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.751266 -> initscore=1.105376
# [LightGBM] [Info] Start training from score 1.105376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    Fold 2 ROC-AUC: 0.8256
# [LightGBM] [Info] Number of positive: 300873, number of negative: 100777
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018998 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8696
# [LightGBM] [Info] Number of data points in the train set: 401650, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.749092 -> initscore=1.093778
# [LightGBM] [Info] Start training from score 1.093778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    Fold 3 ROC-AUC: 0.8252
# [LightGBM] [Info] Number of positive: 297420, number of negative: 104230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019232 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8677
# [LightGBM] [Info] Number of data points in the train set: 401650, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.740495 -> initscore=1.048545
# [LightGBM] [Info] Start training from score 1.048545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    Fold 4 ROC-AUC: 0.8278
# [LightGBM] [Info] Number of positive: 301264, number of negative: 100386
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019436 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8675
# [LightGBM] [Info] Number of data points in the train set: 401650, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.750066 -> initscore=1.098964
# [LightGBM] [Info] Start training from score 1.098964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    Fold 5 ROC-AUC: 0.8453
# ✅ LightGBM Mean ROC-AUC: 0.8281
#
# 🔹 Training AdaBoost...
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#    Fold 1 ROC-AUC: 0.7885
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#    Fold 2 ROC-AUC: 0.8273
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#    Fold 3 ROC-AUC: 0.8145
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#    Fold 4 ROC-AUC: 0.8181
# C:\Users\nudit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#    Fold 5 ROC-AUC: 0.8445
# ✅ AdaBoost Mean ROC-AUC: 0.8186
#
# 🔹 Training CatBoost...
#    Fold 1 ROC-AUC: 0.8231
#    Fold 2 ROC-AUC: 0.8259
#    Fold 3 ROC-AUC: 0.8507
#    Fold 4 ROC-AUC: 0.8266
#    Fold 5 ROC-AUC: 0.8513
# ✅ CatBoost Mean ROC-AUC: 0.8355
#
# 🔹 Training MLP...
#    Fold 1 ROC-AUC: 0.7915
#    Fold 2 ROC-AUC: 0.8221
#    Fold 3 ROC-AUC: 0.7980
#    Fold 4 ROC-AUC: 0.8146
#    Fold 5 ROC-AUC: 0.8253
# ✅ MLP Mean ROC-AUC: 0.8103
#
# 🔹 Training RandomForest...
#    Fold 1 ROC-AUC: 0.8254
#    Fold 2 ROC-AUC: 0.8399
#    Fold 3 ROC-AUC: 0.8338
#    Fold 4 ROC-AUC: 0.8295
#    Fold 5 ROC-AUC: 0.8476
# ✅ RandomForest Mean ROC-AUC: 0.8352

# %%
best_model_name = max(results, key=results.get)
print("\n🏆 Best Model:", best_model_name, "with ROC-AUC:", results[best_model_name])

best_model = models[best_model_name]
# Out:
# 🏆 Best Model: CatBoost with ROC-AUC: 0.8355341179685605

# %%
if best_model_name == "MLP":
    best_model.fit(X_scaled, y)  # use scaled features
else:
    best_model.fit(X, y)         # use raw features

# %%
joblib.dump(best_model, "../rockfall_xgb_final.pkl")
print("✅ Final model saved as rockfall_xgb_final.pkl")
# Out:
# ✅ Final model saved as rockfall_xgb_final.pkl
